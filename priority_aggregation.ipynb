# %%
import os
import numpy as np
from glob import glob
from datetime import datetime

# %%
#paths
input_folder = "data/8.477_47.336_8.605_47.417"
output_folder = os.path.join(input_folder, "aggregated-5pct")
os.makedirs(output_folder, exist_ok=True)

# to load and sort files
def extract_date(filename):
    basename = os.path.basename(filename)
    date_str = basename.split("_")[0]
    return datetime.strptime(date_str, "%Y-%m-%d")

file_paths = sorted(glob(os.path.join(input_folder, "*_mask.npy")), key=extract_date)

# assignment priorities
priority_values = [
    np.array([255, 0, 0]),  # red: building
    np.array([0, 0, 255]),  # blue: water
    np.array([0, 255, 0])  # green: green space
]

# helper
def is_valid(pixel):
    # invalid if empty [0, 0, 0] or cloud [255, 255, 255]
    return not (np.all(pixel == [0, 0, 0]) or np.all(pixel == [255, 255, 255]))

def match_priority(value):
    for p in priority_values:
        if np.all(value == p):
            return True
    return False

def fill_pixels(base, candidate):
    filled = base.copy()
    mask_invalid = (np.all(base == [0, 0, 0], axis=-1) | np.all(base == [255, 255, 255], axis=-1))
    
    for p in priority_values:
        mask_candidate = np.all(candidate == p, axis=-1)
        mask = mask_invalid & mask_candidate
        filled[mask] = p
        mask_invalid[mask] = False  # Update remaining invalid pixels
    return filled

# %%
# aggregation loop
i = 0
n = len(file_paths)

fill_until = 0.95  # fill image until 95 % are valid pixels

while i < n:
    base = np.load(file_paths[i])
    base_date = extract_date(file_paths[i])
    last_used = base_date

    j = i + 1
    while j < n:
        candidate = np.load(file_paths[j])
        base = fill_pixels(base, candidate)
        valid_pixels = np.array([is_valid(px) for px in base.reshape(-1, 3)])
        if valid_pixels.sum() / len(valid_pixels) >= fill_until:
            last_used = extract_date(file_paths[j])
            break
        last_used = extract_date(file_paths[j])
        j += 1

    # Save result
    out_name = f"{last_used.strftime('%Y-%m-%d')}_aggregated_{int(fill_until*100)}_mask.npy"
    out_path = os.path.join(output_folder, out_name)
    np.save(out_path, base)
    print(f"Saved aggregated file: {out_path}")

    # Advance
    i = j + 1
# Out:
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2017-03-28_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2017-04-10_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2017-05-10_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2017-05-27_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2017-06-26_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2017-07-06_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2017-08-15_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2017-08-23_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2017-09-24_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2017-10-17_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2017-11-03_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2018-04-07_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2018-04-25_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2018-05-07_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2018-05-30_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2018-07-09_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2018-07-19_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2018-07-26_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2018-07-31_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2018-08-05_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2018-08-20_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2018-09-09_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2018-09-17_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2018-09-27_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2018-10-07_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2018-10-14_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2018-10-22_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2019-02-14_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2019-02-21_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2019-02-26_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2019-03-21_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2019-03-28_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2019-04-20_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2019-06-01_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2019-06-19_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2019-06-26_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2019-07-04_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2019-07-24_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2019-08-08_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2019-08-25_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2019-08-30_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2019-09-12_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2019-09-29_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2019-10-14_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2019-12-03_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2020-01-20_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2020-03-25_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2020-04-04_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2020-04-09_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2020-04-14_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2020-05-19_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2020-05-29_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2020-06-23_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2020-07-05_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2020-07-30_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2020-08-09_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2020-09-03_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2020-09-13_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2020-11-12_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2021-03-02_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2021-04-04_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2021-04-24_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2021-06-10_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2021-06-18_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2021-07-23_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2021-08-14_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2021-09-03_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2021-09-13_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2021-10-01_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2021-10-23_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2022-02-05_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2022-02-10_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2022-02-28_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2022-03-07_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2022-03-20_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2022-03-27_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2022-04-14_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2022-05-11_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2022-06-18_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2022-06-23_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2022-07-03_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2022-07-15_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2022-07-25_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2022-08-09_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2022-08-22_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2022-10-06_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2022-10-26_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2023-03-15_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2023-05-26_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2023-05-31_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2023-06-05_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2023-06-15_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2023-07-15_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2023-09-06_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2023-09-11_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2023-10-01_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2023-10-11_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2023-10-28_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2024-02-03_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2024-05-10_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2024-07-27_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2024-08-06_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2024-08-13_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2024-08-23_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2024-09-07_aggregated_mask.npy
# Saved aggregated file: data/8.477_47.336_8.605_47.417/aggregated-5pct/2024-12-16_aggregated_mask.npy
